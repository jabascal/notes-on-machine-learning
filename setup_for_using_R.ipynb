# %% [markdown]
# # Mount google drive

# %% [markdown]
# Instal require packages and mount google drive for R. For more details of how to use google colab in R, see blog https://towardsdatascience.com/how-to-use-r-in-google-colab-b6e02d736497

# %%
# googledrive allows you to interact with files on Google Drive from R. Install from CRAN:
install.packages("googledrive")
# Load googledrive
library("googledrive")

# %% [markdown]
# Run and neglect error message!

# %%
# authorize google drive
drive_auth(
  email = gargle::gargle_oauth_email(),
  path = NULL,
  scopes = "https://www.googleapis.com/auth/drive",
  cache = gargle::gargle_oauth_cache(),
  use_oob = gargle::gargle_oob_default(),
  token = NULL
)

# %%
  install.packages("R.utils")
  library("R.utils")
  library("httr")
  my_check <- function() {return(TRUE)}
  reassignInPackage("is_interactive", pkgName = "httr", my_check) 
  options(rlang_interactive=TRUE)

# %%
Give authorization to access your google drive:

# %%
drive_auth(use_oob = TRUE, cache = TRUE)

# %% [markdown]
# # Open new notebook for R

# %% [markdown]
# Open a new notebook for R using the link  https://colab.to/r
